# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("students.csv")
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df2 = pd.read_excel("accounts.xlsx", header=2)
df2
# Out:
#      Region                    Type               Reference  \
# 0    Multan       Expenses-Salaries       Expenses-Salaries
# 1    Multan       Expenses-Salaries       Expenses-Salaries
# 2    Multan  Expenses-Entertainment  Expenses-Entertainment
# 3    Multan           Expenses-Rent           Expenses-Rent
# 4    Multan      Expenses-Utilities      Expenses-Utilities
# ..      ...                     ...                     ...
# 232     NaN                     NaN                     NaN
# 233     NaN                     NaN                     NaN
# 234     NaN                     NaN                     NaN
# 235     NaN                     NaN                     NaN
# 236     NaN                     NaN                     NaN
#
#              Head ( expenses)       January  Feburary    March    April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0  42500.0  42500.0
# 1    Salaries of loader Staff  35000.000000   35000.0  35000.0  35000.0
# ...

# %%
del df2["Unnamed: 16"]
df2
# Out:
#      Region                    Type               Reference  \
# 0    Multan       Expenses-Salaries       Expenses-Salaries
# 1    Multan       Expenses-Salaries       Expenses-Salaries
# 2    Multan  Expenses-Entertainment  Expenses-Entertainment
# 3    Multan           Expenses-Rent           Expenses-Rent
# 4    Multan      Expenses-Utilities      Expenses-Utilities
# ..      ...                     ...                     ...
# 232     NaN                     NaN                     NaN
# 233     NaN                     NaN                     NaN
# 234     NaN                     NaN                     NaN
# 235     NaN                     NaN                     NaN
# 236     NaN                     NaN                     NaN
#
#              Head ( expenses)       January  Feburary    March    April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0  42500.0  42500.0
# 1    Salaries of loader Staff  35000.000000   35000.0  35000.0  35000.0
# ...

# %%
df2.describe()
# Out:
#             January      Feburary         March         April           May  \
# count  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02
# mean   6.801716e+05  8.891690e+05  1.604949e+06  1.130535e+06  1.657942e+06
# std    3.832684e+06  4.415471e+06  8.891416e+06  5.360130e+06  9.063953e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.350000e+03  2.393000e+03  8.000000e+02
# 50%    1.797204e+03  2.200000e+04  3.150000e+04  3.500000e+04  2.444700e+04
# 75%    8.222358e+04  1.729480e+05  2.562981e+05  2.166700e+05  2.439390e+05
# max    4.166743e+07  4.453336e+07  8.293276e+07  4.605104e+07  8.031265e+07
#
#                June          July        August     September       October  \
# count  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02
# mean   1.442919e+06  1.363090e+06  1.058929e+06  1.183439e+06  1.054115e+06
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Region            165 non-null    object
#  1   Type              165 non-null    object
#  2   Reference         165 non-null    object
#  3   Head ( expenses)  165 non-null    object
#  4   January           165 non-null    float64
#  5   Feburary          165 non-null    float64
#  6   March             165 non-null    float64
#  7   April             165 non-null    float64
#  8   May               165 non-null    float64
#  9   June              165 non-null    float64
#  10  July              165 non-null    float64
#  11  August            165 non-null    float64
#  12  September         165 non-null    float64
#  13  October           165 non-null    float64
#  14  November          165 non-null    float64
#  15  December          165 non-null    float64
# ...

# %%
mdf = df2.dropna()
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
# 164    Total                   Total                   Total
#
#              Head ( expenses)       January  Feburary      March       April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0   42500.00   42500.000
# ...

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 0 to 164
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Region            165 non-null    object
#  1   Type              165 non-null    object
#  2   Reference         165 non-null    object
#  3   Head ( expenses)  165 non-null    object
#  4   January           165 non-null    float64
#  5   Feburary          165 non-null    float64
#  6   March             165 non-null    float64
#  7   April             165 non-null    float64
#  8   May               165 non-null    float64
#  9   June              165 non-null    float64
#  10  July              165 non-null    float64
#  11  August            165 non-null    float64
#  12  September         165 non-null    float64
#  13  October           165 non-null    float64
#  14  November          165 non-null    float64
#  15  December          165 non-null    float64
# ...

# %%
mdf["Region"].unique()
# Out:
# array(['Multan', 'Total', 'Sukkur', 'ISB/RWP', 'Hyderabad', 'KPK',
#        'Karachi', 'HO-AKC', 'HO-SQT', 'HO-AKT', 'Total Expenses', 'ABT',
#        'QTA'], dtype=object)

# %%
mdf[mdf["Region"] == "Total"]
# Out:
#     Region   Type Reference Head ( expenses)       January     Feburary  \
# 10   Total  Total     Total            Total  1.897410e+05   340981.000
# 21   Total  Total     Total            Total  7.337400e+04   166670.000
# 33   Total  Total     Total            Total  2.804000e+05   656900.000
# 43   Total  Total     Total            Total  1.057140e+05   233338.000
# 54   Total  Total     Total            Total  0.000000e+00   177101.000
# 65   Total  Total     Total            Total  0.000000e+00        0.000
# 76   Total  Total     Total            Total  7.838700e+04   388640.000
# 87   Total  Total     Total            Total  8.931132e+05  1172957.136
# 97   Total  Total     Total            Total  8.222358e+04   220388.040
# 107  Total  Total     Total            Total  2.129795e+06  2229807.696
# 117  Total  Total     Total            Total  2.044445e+05   210382.176
# 127  Total  Total     Total            Total  1.031536e+06  1194620.820
# ...

# %%
mdf = mdf[mdf["Region"] != "Total"]
mdf = mdf[mdf["Region"] != "Total Expenses"]
mdf["Region"].unique()
# Out:
# array(['Multan', 'Sukkur', 'ISB/RWP', 'Hyderabad', 'KPK', 'Karachi',
#        'HO-AKC', 'HO-SQT', 'HO-AKT', 'ABT', 'QTA'], dtype=object)

# %%
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#              Head ( expenses)       January  Feburary     March      April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0  42500.00  42500.000
# 1    Salaries of loader Staff  35000.000000   35000.0  35000.00  35000.000
# ...

# %%
mdf["Type"].unique()
# Out:
# array(['Expenses-Salaries', 'Expenses-Entertainment', 'Expenses-Rent',
#        'Expenses-Utilities', 'Expenses-Freight', 'Expenses-Misc',
#        'Expenses-Professional Charges', 'Primary Sale', 'Income', 'COS',
#        'Expense', 'COS.'], dtype=object)

# %%
mdf["Reference"].unique()
# Out:
# array(['Expenses-Salaries', 'Expenses-Entertainment', 'Expenses-Rent',
#        'Expenses-Utilities', 'Expenses-Freight', 'Expenses-Misc',
#        'Expenses-Professional Charges', 'Fruitien', "LMT's", "Sole LMT's",
#        'Sole', 'Freight', 'TTS', 'Sole Allocated', 'Freight Allocated',
#        '0.4% Expense', '1. Freight of SQT in AKC', '1. TTS of SQT in AKC',
#        '1. Adjustment of 0.4% exp.', '2. Adjustment of 0.4% exp.',
#        '2. Freight of SQT in AKC', '2. TTS of SQT in AKC'], dtype=object)

# %%
mdf = mdf.rename(columns={"Head ( expenses)":"Head_of_Account"})
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#               Head_of_Account       January  Feburary     March      April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0  42500.00  42500.000
# 1    Salaries of loader Staff  35000.000000   35000.0  35000.00  35000.000
# ...

# %%
mdf.Head_of_Account.unique()
# Out:
# array(['Salaries of Admin Staff', 'Salaries of loader Staff',
#        'Entertainment Expenses', 'Rent Expense', 'Utility Expenses',
#        'Frieght Local', 'Frieght  outstation',
#        'Loading/Unloading Expenses', 'Sationery, Courior and MISC',
#        'Miscellaneous expenses', 'Frieght local', 'Salaries of Salesmen',
#        'Salaries of waseem', 'Salaries of aqeel/usman',
#        'Sationery+Water+Internet+tonner', 'Rent AKC', 'Rent SQT',
#        'Utility Expenses AKC', 'Aqeel alam AKC', 'Aqeel alam SQT',
#        'Aqeel alam AKT', 'Aqeel alam IPO and marketiers', 'Fruitien',
#        "LMT's", "Sole LMT's", 'Sole', 'Freight', 'TTS', 'Sole Allocated',
#        'Freight Allocated', '0.4% Expense', '1. Freight of SQT in AKC',
#        '1. TTS of SQT in AKC', '1. Adjustment of 0.4% exp.',
#        '2. Adjustment of 0.4% exp.', '2. Freight of SQT in AKC',
#        '2. TTS of SQT in AKC'], dtype=object)

# %%
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#               Head_of_Account       January  Feburary     March      April  \
# 0     Salaries of Admin Staff  26370.967742   42500.0  42500.00  42500.000
# 1    Salaries of loader Staff  35000.000000   35000.0  35000.00  35000.000
# ...

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 0 to 163
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           148 non-null    object
#  1   Type             148 non-null    object
#  2   Reference        148 non-null    object
#  3   Head_of_Account  148 non-null    object
#  4   January          148 non-null    float64
#  5   Feburary         148 non-null    float64
#  6   March            148 non-null    float64
#  7   April            148 non-null    float64
#  8   May              148 non-null    float64
#  9   June             148 non-null    float64
#  10  July             148 non-null    float64
#  11  August           148 non-null    float64
#  12  September        148 non-null    float64
#  13  October          148 non-null    float64
#  14  November         148 non-null    float64
#  15  December         148 non-null    float64
# dtypes: float64(12), object(4)
# ...

# %%
mdf.loc[:, "January":"December"]
# Out:
#      January  Feburary  March  April    May   June   July  August  September  \
# 0      26370     42500  42500  42500  49354  42500  42500   42500      42500
# 1      35000     35000  35000  35000  35000  35000  35000   35000      35000
# 2          0      6000   9000   4400   6500   9355   6800    5300       6000
# 3      44000     44000  44000  44000  44000  44000  44000   44000      44000
# 4          0      6788   5912   5802   6506   9366  10716   16411      15493
# ..       ...       ...    ...    ...    ...    ...    ...     ...        ...
# 159        0         0      0      0      0      0      0       0          0
# 160        0         0   3141   3806   1658   5969      0       0          0
# 161        0         0      0      0      0      0      0       0          0
# 162        0         0      0      0      0      0      0       0          0
# 163        0         0    758   1046    168    397      0       0          0
#
#      October  November  December
# ...

# %%
mdf.loc[:, "January":"December"] = mdf.loc[:, "January":"December"].astype(int)
mdf.loc[:, "January":"December"].dtypes
# Out:
# January      int32
# Feburary     int32
# March        int32
# April        int32
# May          int32
# June         int32
# July         int32
# August       int32
# September    int32
# October      int32
# November     int32
# December     int32
# dtype: object

# %%
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#               Head_of_Account  January  Feburary  March  April    May   June  \
# 0     Salaries of Admin Staff    26370     42500  42500  42500  49354  42500
# ...

# %%
# create a sample pivoted dataframe
data = {'name': ['Alice', 'Bob', 'Charlie'],
        'week1': [10, 20, 30],
        'week2': [15, 25, 35],
        'week3': [20, 30, 40]}

data
# Out:
# {'name': ['Alice', 'Bob', 'Charlie'],
#  'week1': [10, 20, 30],
#  'week2': [15, 25, 35],
#  'week3': [20, 30, 40]}

# %%
df3 = pd.DataFrame(data)
df3
# Out:
#       name  week1  week2  week3
# 0    Alice     10     15     20
# 1      Bob     20     25     30
# 2  Charlie     30     35     40

# %%
# unpivot the dataframe using melt()
df_unpivoted = df3.reset_index().melt(id_vars='name', var_name='week', value_name='value')
print(df_unpivoted)
# Out:
#        name   week  value
# 0     Alice  index      0
# 1       Bob  index      1
# 2   Charlie  index      2
# 3     Alice  week1     10
# 4       Bob  week1     20
# 5   Charlie  week1     30
# 6     Alice  week2     15
# 7       Bob  week2     25
# 8   Charlie  week2     35
# 9     Alice  week3     20
# 10      Bob  week3     30
# 11  Charlie  week3     40

# %%
# unpivot the dataframe using melt()
df_unpivoted = df3.melt(id_vars='name', var_name='week', value_name='value')
print(df_unpivoted)
# Out:
#       name   week  value
# 0    Alice  week1     10
# 1      Bob  week1     20
# 2  Charlie  week1     30
# 3    Alice  week2     15
# 4      Bob  week2     25
# 5  Charlie  week2     35
# 6    Alice  week3     20
# 7      Bob  week3     30
# 8  Charlie  week3     40

# %%
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#               Head_of_Account  January  Feburary  March  April    May   June  \
# 0     Salaries of Admin Staff    26370     42500  42500  42500  49354  42500
# ...

# %%
fdf = mdf.melt(id_vars=["Region", "Type", "Reference", "Head_of_Account"], var_name="Month")
fdf
# Out:
#        Region                    Type               Reference  \
# 0      Multan       Expenses-Salaries       Expenses-Salaries
# 1      Multan       Expenses-Salaries       Expenses-Salaries
# 2      Multan  Expenses-Entertainment  Expenses-Entertainment
# 3      Multan           Expenses-Rent           Expenses-Rent
# 4      Multan      Expenses-Utilities      Expenses-Utilities
# ...       ...                     ...                     ...
# 1771  Karachi                  Income                 Freight
# 1772  Karachi                  Income                     TTS
# 1773  Karachi                     COS          Sole Allocated
# 1774  Karachi                     COS       Freight Allocated
# 1775  Karachi                 Expense            0.4% Expense
#
#                Head_of_Account     Month  value
# 0      Salaries of Admin Staff   January  26370
# 1     Salaries of loader Staff   January  35000
# 2       Entertainment Expenses   January      0
# ...

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           1776 non-null   object
#  1   Type             1776 non-null   object
#  2   Reference        1776 non-null   object
#  3   Head_of_Account  1776 non-null   object
#  4   Month            1776 non-null   object
#  5   value            1776 non-null   int32
# dtypes: int32(1), object(5)
# memory usage: 76.4+ KB

# %%
fdf[fdf['value'] == 0]
# Out:
#        Region                    Type               Reference  \
# 2      Multan  Expenses-Entertainment  Expenses-Entertainment
# 4      Multan      Expenses-Utilities      Expenses-Utilities
# 7      Multan        Expenses-Freight        Expenses-Freight
# 8      Multan           Expenses-Misc           Expenses-Misc
# 9      Multan           Expenses-Misc           Expenses-Misc
# ...       ...                     ...                     ...
# 1771  Karachi                  Income                 Freight
# 1772  Karachi                  Income                     TTS
# 1773  Karachi                     COS          Sole Allocated
# 1774  Karachi                     COS       Freight Allocated
# 1775  Karachi                 Expense            0.4% Expense
#
#                   Head_of_Account     Month  value
# 2          Entertainment Expenses   January      0
# 4                Utility Expenses   January      0
# 7      Loading/Unloading Expenses   January      0
# ...

# %%
fdf = fdf[fdf['value'] != 0]
fdf
# Out:
#        Region               Type          Reference           Head_of_Account  \
# 0      Multan  Expenses-Salaries  Expenses-Salaries   Salaries of Admin Staff
# 1      Multan  Expenses-Salaries  Expenses-Salaries  Salaries of loader Staff
# 3      Multan      Expenses-Rent      Expenses-Rent              Rent Expense
# 5      Multan   Expenses-Freight   Expenses-Freight             Frieght Local
# 6      Multan   Expenses-Freight   Expenses-Freight       Frieght  outstation
# ...       ...                ...                ...                       ...
# 1762      QTA             Income            Freight                   Freight
# 1763      QTA             Income                TTS                       TTS
# 1765      QTA                COS  Freight Allocated         Freight Allocated
# 1766      QTA            Expense       0.4% Expense              0.4% Expense
# 1767  Karachi       Primary Sale           Fruitien                  Fruitien
#
#          Month    value
# ...

# %% [markdown]
# # Time series Maniuplation is pending

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
fdf
# Out:
#        Region               Type          Reference           Head_of_Account  \
# 0      Multan  Expenses-Salaries  Expenses-Salaries   Salaries of Admin Staff
# 1      Multan  Expenses-Salaries  Expenses-Salaries  Salaries of loader Staff
# 3      Multan      Expenses-Rent      Expenses-Rent              Rent Expense
# 5      Multan   Expenses-Freight   Expenses-Freight             Frieght Local
# 6      Multan   Expenses-Freight   Expenses-Freight       Frieght  outstation
# ...       ...                ...                ...                       ...
# 1762      QTA             Income            Freight                   Freight
# 1763      QTA             Income                TTS                       TTS
# 1765      QTA                COS  Freight Allocated         Freight Allocated
# 1766      QTA            Expense       0.4% Expense              0.4% Expense
# 1767  Karachi       Primary Sale           Fruitien                  Fruitien
#
#          Month    value
# ...

# %%
mdf
# Out:
#       Region                    Type               Reference  \
# 0     Multan       Expenses-Salaries       Expenses-Salaries
# 1     Multan       Expenses-Salaries       Expenses-Salaries
# 2     Multan  Expenses-Entertainment  Expenses-Entertainment
# 3     Multan           Expenses-Rent           Expenses-Rent
# 4     Multan      Expenses-Utilities      Expenses-Utilities
# ..       ...                     ...                     ...
# 159  Karachi                  Income                 Freight
# 160  Karachi                  Income                     TTS
# 161  Karachi                     COS          Sole Allocated
# 162  Karachi                     COS       Freight Allocated
# 163  Karachi                 Expense            0.4% Expense
#
#               Head_of_Account  January  Feburary  March  April    May   June  \
# 0     Salaries of Admin Staff    26370     42500  42500  42500  49354  42500
# ...
