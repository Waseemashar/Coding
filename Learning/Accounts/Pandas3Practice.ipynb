# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("students.csv")
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student Code          48 non-null     object
#  1   Degree                48 non-null     object
#  2   Student Name          48 non-null     object
#  3   Mid                   48 non-null     int64
#  4   Quiz 1                45 non-null     float64
#  5   Quiz 2                45 non-null     float64
#  6   Best of Quizzes       48 non-null     int64
#  7   Assignment 1          45 non-null     float64
#  8   Assignment 2          36 non-null     float64
#  9   Best of Assignments   48 non-null     int64
#  10  Total Sessional (50)  48 non-null     int64
#  11  Final (50)            47 non-null     float64
#  12  Total (100)           48 non-null     int64
#  13  Grade                 48 non-null     object
# dtypes: float64(5), int64(5), object(4)
# ...

# %%
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student Code          48 non-null     object
#  1   Degree                48 non-null     object
#  2   Student Name          48 non-null     object
#  3   Mid                   48 non-null     int64
#  4   Quiz 1                48 non-null     float64
#  5   Quiz 2                48 non-null     float64
#  6   Best of Quizzes       48 non-null     int64
#  7   Assignment 1          48 non-null     float64
#  8   Assignment 2          48 non-null     float64
#  9   Best of Assignments   48 non-null     int64
#  10  Total Sessional (50)  48 non-null     int64
#  11  Final (50)            48 non-null     float64
#  12  Total (100)           48 non-null     int64
#  13  Grade                 48 non-null     object
# dtypes: float64(5), int64(5), object(4)
# ...

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     0.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df["Status"] = ["Fail" if i == "F" else "Pass" for i in df["Grade"]]
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     0.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.drop("Degree", axis=1, inplace=True)

# %%
df["Message"] = df["Status"].apply(lambda x: "Congrats" if x == "Pass" else "Try Harder")
df
# Out:
#      Student Code                    Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987                     Abdul Basit   28     8.0     3.0
# 1   022-14-110233                     Adeel Ahmed   17     0.0     5.0
# 2   022-14-110585                    Afrah Zareen   18     5.0     2.0
# 3    022-14-19718                  Ahmed Ali Raza   14     7.0     2.0
# 4   022-14-110648                 Ahsan Ali Vohra   27     7.0     6.0
# 5   022-14-110232                     Ameer Hamza   25     9.0     6.0
# 6   022-14-110588                   Anas Ali Khan   28     5.0     6.0
# 7   022-14-110388                Aneebullah Niazi   26     9.0     6.0
# 8   022-14-110601                  Areesha Sohail   19     9.0     4.0
# 9   022-14-110599                         Arsalan   28     8.0     6.0
# 10  022-14-110214             Fatima Haider Warsi   30     8.0     7.0
# 11  022-14-110591                     Habib Ullah   28     8.0     5.0
# ...

# %%
df["Status"].value_counts()
# Out:
# Pass    37
# Fail    11
# Name: Status, dtype: int64

# %%
df["Status"].value_counts().sum()
# Out:
# 48

# %%
df["Status"].unique()
# Out:
# array(['Pass', 'Fail'], dtype=object)

# %%
df["Status"].nunique()
# Out:
# 2

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
